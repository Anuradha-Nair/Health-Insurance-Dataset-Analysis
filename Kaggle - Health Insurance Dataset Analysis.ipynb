# %% [markdown]
# # Health Insurance Dataset Analysis

# %% [markdown]
# #### * Importing the dependencies

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### * Loading the Dataset

# %%
# Load the uploaded dataset
df = pd.read_csv(r"C:\Users\DELL\OneDrive\Documents\healthcare_insurance_1.csv")

# %% [markdown]
# ### Overview of the Healthcare Insurance Dataset

# %%
# Display basic information about the dataset
df.info(), df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB
# (None,
#     age     sex     bmi  children smoker     region      charges
#  0   19  female  27.900         0    yes  southwest  16884.92400
#  1   18    male  33.770         1     no  southeast   1725.55230
#  2   28    male  33.000         3     no  southeast   4449.46200
#  3   33    male  22.705         0     no  northwest  21984.47061
#  4   32    male  28.880         0     no  northwest   3866.85520)

# %% [markdown]
# ## Step-by-Step Analysis of the Healthcare Insurance Dataset

# %% [markdown]
# ### 🔍 Step 1: Data Overview

# %%
from IPython.display import display, HTML

display(HTML("""
<div style="text-align: center; font-family: Arial, sans-serif; padding: 20px;">

  <h2 style="color:#2F4F4F;">📋 Dataset Schema: Healthcare Insurance</h2>

  <table border="1" style="margin: 0 auto; border-collapse: collapse; width: 75%; background-color: #ffffff; color: #000000;">
    <thead style="background-color: #e0f7fa;">
      <tr>
        <th style="padding: 12px;">Column</th>
        <th style="padding: 12px;">Description</th>
        <th style="padding: 12px;">Type</th>
      </tr>
    </thead>
    <tbody>
      <tr>
        <td style="padding: 10px;">age</td>
        <td style="padding: 10px;">Age of primary beneficiary</td>
        <td style="padding: 10px;">Integer</td>
      </tr>
      <tr>
        <td style="padding: 10px;">sex</td>
        <td style="padding: 10px;">Gender of the beneficiary</td>
        <td style="padding: 10px;">Object</td>
      </tr>
      <tr>
        <td style="padding: 10px;">bmi</td>
        <td style="padding: 10px;">Body Mass Index</td>
        <td style="padding: 10px;">Float</td>
      </tr>
      <tr>
        <td style="padding: 10px;">children</td>
        <td style="padding: 10px;">Number of dependents</td>
        <td style="padding: 10px;">Integer</td>
      </tr>
      <tr>
        <td style="padding: 10px;">smoker</td>
        <td style="padding: 10px;">Smoking status</td>
        <td style="padding: 10px;">Object</td>
      </tr>
      <tr>
        <td style="padding: 10px;">region</td>
        <td style="padding: 10px;">Residential region in the US</td>
        <td style="padding: 10px;">Object</td>
      </tr>
      <tr>
        <td style="padding: 10px;">charges</td>
        <td style="padding: 10px;">Medical insurance cost (target)</td>
        <td style="padding: 10px;">Float</td>
      </tr>
    </tbody>
  </table>

</div>
"""))
# Out:
# <div style="text-align: center; font-family: Arial, sans-serif; padding: 20px;">
#
#   <h2 style="color:#2F4F4F;">📋 Dataset Schema: Healthcare Insurance</h2>
#
#   <table border="1" style="margin: 0 auto; border-collapse: collapse; width: 75%; background-color: #ffffff; color: #000000;">
#     <thead style="background-color: #e0f7fa;">
#       <tr>
#         <th style="padding: 12px;">Column</th>
#         <th style="padding: 12px;">Description</th>
#         <th style="padding: 12px;">Type</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td style="padding: 10px;">age</td>
#         <td style="padding: 10px;">Age of primary beneficiary</td>
#         <td style="padding: 10px;">Integer</td>
#       </tr>
#       <tr>
#         <td style="padding: 10px;">sex</td>
#         <td style="padding: 10px;">Gender of the beneficiary</td>
#         <td style="padding: 10px;">Object</td>
#       </tr>
#       <tr>
#         <td style="padding: 10px;">bmi</td>
# ...

# %% [markdown]
# #### Observations:
#
#         ✅ No missing values
#         ✅ All data types are appropriate

# %% [markdown]
# ### 📊 Step 2: Exploratory Data Analysis (EDA)

# %% [markdown]
# #### Steps:
#
#     1. Summary statistics
#
#     2. Distribution plots (age, BMI, charges)
#
#     3. Categorical value counts (sex, smoker, region)
#
#     4. Boxplots and violin plots to explore relationships
#
#     5. Correlation heatmap
#
#     6. Business insights and potential decisions

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set visual theme
sns.set(style="whitegrid")

# Summary statistics
summary_stats = df.describe(include='all')

# Plot distributions
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Age distribution
sns.histplot(df['age'], bins=20, kde=True, ax=axes[0, 0], color='skyblue')
axes[0, 0].set_title('Age Distribution')

# BMI distribution
sns.histplot(df['bmi'], bins=20, kde=True, ax=axes[0, 1], color='salmon')
axes[0, 1].set_title('BMI Distribution')

# Charges distribution
sns.histplot(df['charges'], bins=30, kde=True, ax=axes[1, 0], color='lightgreen')
axes[1, 0].set_title('Insurance Charges Distribution')

# Children count
sns.countplot(x='children', data=df, ax=axes[1, 1], palette='pastel')
axes[1, 1].set_title('Number of Children')

plt.tight_layout()
plt.show()

summary_stats
# Out:
#                 age   sex          bmi     children smoker     region  \
# count   1338.000000  1338  1338.000000  1338.000000   1338       1338
# unique          NaN     2          NaN          NaN      2          4
# top             NaN  male          NaN          NaN     no  southeast
# freq            NaN   676          NaN          NaN   1064        364
# mean      39.207025   NaN    30.663397     1.094918    NaN        NaN
# std       14.049960   NaN     6.098187     1.205493    NaN        NaN
# min       18.000000   NaN    15.960000     0.000000    NaN        NaN
# 25%       27.000000   NaN    26.296250     0.000000    NaN        NaN
# 50%       39.000000   NaN    30.400000     1.000000    NaN        NaN
# 75%       51.000000   NaN    34.693750     2.000000    NaN        NaN
# max       64.000000   NaN    53.130000     5.000000    NaN        NaN
#
#              charges
# count    1338.000000
# unique           NaN
# top              NaN
# freq             NaN
# ...

# %% [markdown]
# ### 🧠 Insights from Summary Statistics & Distributions

# %% [markdown]
# #### 1. Age:
#
#         Uniform distribution across 18 to 64.
#
#         Median age is 39.
#
#         --> Business Insight: Product offerings can be segmented by age bands (e.g., <30, 30–50, >50) for personalized insurance products.
#
# #### 2. BMI:
#
#         Mean BMI ≈ 30.6 — borderline obese.
#
#         Right-skewed distribution: some outliers above 45.
#
#         --> Actionable Decision: Introduce wellness programs or discounts for customers maintaining healthy BMI levels.
#
# #### 3. Charges:
#
#         Highly right-skewed: mean ≈ $13,270, but max ≈ $63,770.
#
#         Median is much lower ($9,382), indicating a few high-cost individuals.
#
#         --> Business Action: Consider reinsurance or premium tiers for high-risk groups (e.g., older smokers with high BMI).
#
# #### 4. Children
#         Most customers have ≤ 2 children.
#
#         --> Strategy: Family plans can be tiered based on number of children.

# %% [markdown]
# ##### NEXT: Categorical value analysis and relationship plots like boxplots and heatmaps.

# %%
# Count plots for categorical variables
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Sex
sns.countplot(x='sex', data=df, ax=axes[0], palette='coolwarm')
axes[0].set_title('Gender Distribution')

# Smoker
sns.countplot(x='smoker', data=df, ax=axes[1], palette='Set2')
axes[1].set_title('Smoker Distribution')

# Region
sns.countplot(x='region', data=df, ax=axes[2], palette='Set3')
axes[2].set_title('Region Distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 🔍 Categorical Analysis
#
# #### ✅ Gender Distribution:
#
#         Balanced: ~50% male and female.
#
#         --> No immediate business bias, but segmented marketing could still help.
#
# #### 🚬 Smoker Status:
#
#         Majority are non-smokers (~80%), but smokers may be driving high charges.
#
#         --> Business Insight: Risk-adjusted pricing for smokers is essential.
#
# #### 🌍 Region:
#
#         Fairly balanced regional spread, with slightly more customers in the southeast.
#
#         --> Targeted regional marketing campaigns or network partnerships could optimize operations.

# %% [markdown]
# #### NEXT: Exploring relationships between variables (e.g., smoker vs. charges, BMI vs. charges, etc.) using boxplots and heatmaps.

# %%
# Relationship plots
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# Charges by smoker
sns.boxplot(x='smoker', y='charges', data=df, ax=axes[0, 0], palette='Set2')
axes[0, 0].set_title('Charges by Smoker Status')

# Charges by region
sns.boxplot(x='region', y='charges', data=df, ax=axes[0, 1], palette='Set3')
axes[0, 1].set_title('Charges by Region')

# Charges by number of children
sns.boxplot(x='children', y='charges', data=df, ax=axes[1, 0], palette='coolwarm')
axes[1, 0].set_title('Charges by Number of Children')

# Charges vs BMI (with smoker hue)
sns.scatterplot(x='bmi', y='charges', hue='smoker', data=df, ax=axes[1, 1], palette='husl')
axes[1, 1].set_title('Charges vs BMI Colored by Smoker')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 📈 Relationship Insights
#
# #### 1. Smoker Status vs. Charges
#
#         Smokers pay significantly higher charges (often >$30,000).
#
#         --> Business Action: High-risk group—consider targeted intervention programs, higher premium brackets, or preventive care plans.
#
# #### 2. Region vs. Charges
#
#         No substantial difference in charges across regions.
#
#         --> Action: Pricing strategy doesn't need regional customization, but regional campaigns may still help increase market share.
#
# #### 3. Children vs. Charges
#
#         No strong impact of number of children on charges.
#
#         --> Action: Children might not heavily influence premiums — could simplify family plan pricing tiers.
#
# #### 4. BMI vs. Charges (Colored by Smoker)
#
#         Smokers with high BMI are heavily concentrated at high charges.
#
#         --> Action: These are high-risk individuals. Create targeted campaigns offering:
#
#                 * Smoking cessation support
#
#                 * Weight-loss incentives
#
#                 * Tiered pricing

# %% [markdown]
# ### 🔥 Correlation Heatmap

# %% [markdown]
# #### Checking correlations between numeric variables

# %%
# Correlation heatmap
plt.figure(figsize=(8, 6))
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# #### 📊 Correlation Heatmap – Key Takeaways

# %%
from IPython.display import display, HTML

display(HTML("""
<div style="text-align: center; font-family: Arial, sans-serif; padding: 20px;">

  <h2 style="color:#2F4F4F;">🔗 Correlation Summary</h2>

  <table border="1" style="margin: 0 auto; border-collapse: collapse; width: 80%; background-color: #ffffff; color: #000000;">
    <thead style="background-color: #e0f7fa;">
      <tr>
        <th style="padding: 12px;">Variable Pair</th>
        <th style="padding: 12px;">Correlation</th>
        <th style="padding: 12px;">Interpretation</th>
      </tr>
    </thead>
    <tbody>
      <tr>
        <td style="padding: 10px;">age vs charges</td>
        <td style="padding: 10px;">+0.30</td>
        <td style="padding: 10px;">Older individuals tend to have higher medical costs.</td>
      </tr>
      <tr>
        <td style="padding: 10px;">bmi vs charges</td>
        <td style="padding: 10px;">+0.20</td>
        <td style="padding: 10px;">Moderate positive correlation. Stronger when smoker is involved.</td>
      </tr>
      <tr>
        <td style="padding: 10px;">children vs charges</td>
        <td style="padding: 10px;">+0.07</td>
        <td style="padding: 10px;">Very weak — not impactful.</td>
      </tr>
      <tr>
        <td style="padding: 10px;">age vs bmi</td>
        <td style="padding: 10px;">~0.10</td>
        <td style="padding: 10px;">No significant age-related BMI trend.</td>
      </tr>
    </tbody>
  </table>

</div>
"""))
# Out:
# <div style="text-align: center; font-family: Arial, sans-serif; padding: 20px;">
#
#   <h2 style="color:#2F4F4F;">🔗 Correlation Summary</h2>
#
#   <table border="1" style="margin: 0 auto; border-collapse: collapse; width: 80%; background-color: #ffffff; color: #000000;">
#     <thead style="background-color: #e0f7fa;">
#       <tr>
#         <th style="padding: 12px;">Variable Pair</th>
#         <th style="padding: 12px;">Correlation</th>
#         <th style="padding: 12px;">Interpretation</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td style="padding: 10px;">age vs charges</td>
#         <td style="padding: 10px;">+0.30</td>
#         <td style="padding: 10px;">Older individuals tend to have higher medical costs.</td>
#       </tr>
#       <tr>
#         <td style="padding: 10px;">bmi vs charges</td>
#         <td style="padding: 10px;">+0.20</td>
#         <td style="padding: 10px;">Moderate positive correlation. Stronger when smoker is involved.</td>
# ...

# %% [markdown]
# ## ✅ EDA Conclusion: Business Decisions

# %%
from IPython.display import display, HTML

display(HTML("""
<div style="text-align: center; font-family: Arial, sans-serif; padding: 20px;">

  <h2 style="color:#2F4F4F;">✅ EDA Conclusion: Business Decisions</h2>

  <table border="1" style="margin: 0 auto; border-collapse: collapse; width: 90%; background-color: #ffffff; color: #000000;">
    <thead style="background-color: #c8e6c9;">
      <tr>
        <th style="padding: 12px;">Observation</th>
        <th style="padding: 12px;">Business Implication</th>
      </tr>
    </thead>
    <tbody>
      <tr>
        <td style="padding: 10px;">Smokers have significantly higher insurance charges.</td>
        <td style="padding: 10px;">Introduce higher premiums or incentivize smoking cessation programs.</td>
      </tr>
      <tr>
        <td style="padding: 10px;">BMI is moderately correlated with charges, especially among smokers.</td>
        <td style="padding: 10px;">Implement wellness programs targeting weight management.</td>
      </tr>
      <tr>
        <td style="padding: 10px;">Age is positively correlated with insurance charges.</td>
        <td style="padding: 10px;">Adjust premiums based on age brackets to manage risk.</td>
      </tr>
      <tr>
        <td style="padding: 10px;">Number of children has minimal effect on charges.</td>
        <td style="padding: 10px;">No immediate need to adjust policy based on dependents.</td>
      </tr>
      <tr>
        <td style="padding: 10px;">Region has minor variation in charges.</td>
        <td style="padding: 10px;">Consider regional marketing or localized pricing if needed.</td>
      </tr>
    </tbody>
  </table>

</div>
"""))
# Out:
# <div style="text-align: center; font-family: Arial, sans-serif; padding: 20px;">
#
#   <h2 style="color:#2F4F4F;">✅ EDA Conclusion: Business Decisions</h2>
#
#   <table border="1" style="margin: 0 auto; border-collapse: collapse; width: 90%; background-color: #ffffff; color: #000000;">
#     <thead style="background-color: #c8e6c9;">
#       <tr>
#         <th style="padding: 12px;">Observation</th>
#         <th style="padding: 12px;">Business Implication</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td style="padding: 10px;">Smokers have significantly higher insurance charges.</td>
#         <td style="padding: 10px;">Introduce higher premiums or incentivize smoking cessation programs.</td>
#       </tr>
#       <tr>
#         <td style="padding: 10px;">BMI is moderately correlated with charges, especially among smokers.</td>
#         <td style="padding: 10px;">Implement wellness programs targeting weight management.</td>
#       </tr>
#       <tr>
# ...
